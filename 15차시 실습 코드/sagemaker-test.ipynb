# %%
from sagemaker import get_execution_role 
role = get_execution_role() 

############사용자 버킷 이름으로 지정해 주세요############
bucket = 'sagemaker-testark'  # s3 사용자 버킷이름 지정
############사용자 버킷 이름으로 지정해 주세요############

# %%
# %%time 
import pickle, gzip, numpy, urllib.request, json 
# Load the dataset 
urllib.request.urlretrieve("https://raw.githubusercontent.com/ark1st/Big4ML-Sagemaker/master/mnist.pkl.gz", "mnist.pkl.gz") 
with gzip.open('mnist.pkl.gz', 'rb') as f: 
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 938 ms, sys: 252 ms, total: 1.19 s
# Wall time: 3.11 s

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
plt.rcParams["figure.figsize"] = (2,10) # 그림 크기 지정

def show_digit(img, caption=' ', subplot=None): 
    if subplot == None: 
        _, (subplot) = plt.subplots(1,1) 
    imgr = img.reshape((28,28)) 
    subplot.axis('off') 
    subplot.imshow(imgr, cmap='gray') 
    plt.title(caption) 
    
show_digit(train_set[0][30], 'This is a {}'.format(train_set[1][30])) #30번째 데이터 3을 손으로 쓴 이미지

# %%
from sagemaker.amazon.common import write_numpy_to_dense_tensor 
import io 
import boto3 


############사용자 버킷 이름으로 지정해 주세요############
bucket = 'sagemaker-testark' # Amazon S3 버킷 이름 (생성한 버킷과 일치하지 않으면 오류 발생)
############사용자 버킷 이름으로 지정해 주세요############


data_key = 'kmeans_lowlevel_example/data' # 데이터 키 설정
data_location = 's3://{}/{}'.format(bucket, data_key) # 데이터 위치 설정 
print('training data will be uploaded to: {}'.format(data_location)) 

# MNIST 데이터를 Amazon SageMaker 데이터 타입에 맞게 변환 
buf = io.BytesIO() 
write_numpy_to_dense_tensor(buf, train_set[0], train_set[1]) 
buf.seek(0) 
boto3.resource('s3').Bucket(bucket).Object(data_key).upload_fileobj(buf)
# Out:
# training data will be uploaded to: s3://sagemaker-testark/kmeans_lowlevel_example/data

# %%
from sagemaker import KMeans 
data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket) 
output_location = 's3://{}/kmeans_highlevel_example/output'.format(bucket) 
print('training data will be uploaded to: {}'.format(data_location)) 
print('training artifacts will be uploaded to: {}'.format(output_location)) 
kmeans = KMeans(role=role, # 훈련 결과 읽기 및 쓰기에 사용되는 사용자 IAM 
                train_instance_count=2, # 모델 훈련에 사용할 인스턴스의 수 
                train_instance_type='ml.c4.8xlarge', # 모델 훈련에 사용할 인스턴스의 타입 
                output_path=output_location, # 훈련 결과를 저장할 위치 
                k=10, # 생성할 클러스터의 수, 0부터 9까지의 숫자 분류 문제이기에 10으로 설정 
                data_location=data_location) # 변환된 훈련 데이터를 업로드하는 Amazon S3의 위치
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# training data will be uploaded to: s3://sagemaker-testark/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-testark/kmeans_highlevel_example/output

# %%
kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-12-09 14:10:41 Starting - Starting the training job...
# 2021-12-09 14:11:05 Starting - Launching requested ML instancesProfilerReport-1639059041: InProgress
# ......
# 2021-12-09 14:12:05 Starting - Preparing the instances for training.........
# 2021-12-09 14:13:37 Downloading - Downloading input data...
# 2021-12-09 14:14:11 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/09/2021 14:14:07 INFO 140250892990272] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [12/09/2021 14:14:07 INFO 140250892990272] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '784', 'k': '10', 'force_dense': 'True'}
# [12/09/2021 14:14:07 INFO 140250892990272] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [12/09/2021 14:14:07 WARNING 140250892990272] Loggers have already been setup.
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/09/2021 14:14:16 INFO 140151864076096] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [12/09/2021 14:14:16 INFO 140151864076096] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '784', 'k': '10', 'force_dense': 'True'}
# [12/09/2021 14:14:16 INFO 140151864076096] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [12/09/2021 14:14:16 WARNING 140151864076096] Loggers have already been setup.
# [12/09/2021 14:14:16 INFO 140151864076096] Launching parameter server for role scheduler
# [12/09/2021 14:14:16 INFO 140151864076096] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-189-6.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/70c78311-f7a8-4a88-beee-5cfd45d2e95f', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3095a015-5f48-42e7-b196-b13897bf49ae', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3095a015-5f48-42e7-b196-b13897bf49ae', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [12/09/2021 14:14:16 INFO 140151864076096] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-189-6.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/70c78311-f7a8-4a88-beee-5cfd45d2e95f', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3095a015-5f48-42e7-b196-b13897bf49ae', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3095a015-5f48-42e7-b196-b13897bf49ae', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.189.6', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [12/09/2021 14:14:16 INFO 140151864076096] Launching parameter server for role server
# [12/09/2021 14:14:16 INFO 140151864076096] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-189-6.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/70c78311-f7a8-4a88-beee-5cfd45d2e95f', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3095a015-5f48-42e7-b196-b13897bf49ae', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3095a015-5f48-42e7-b196-b13897bf49ae', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [12/09/2021 14:14:16 INFO 140151864076096] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-189-6.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/70c78311-f7a8-4a88-beee-5cfd45d2e95f', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3095a015-5f48-42e7-b196-b13897bf49ae', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3095a015-5f48-42e7-b196-b13897bf49ae', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.189.6', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [12/09/2021 14:14:16 INFO 140151864076096] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-189-6.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/70c78311-f7a8-4a88-beee-5cfd45d2e95f', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3095a015-5f48-42e7-b196-b13897bf49ae', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3095a015-5f48-42e7-b196-b13897bf49ae', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.189.6', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 82 is a shell:scheduler.
# Process 91 is a shell:server.
# Process 1 is a worker.
# [12/09/2021 14:14:16 INFO 140151864076096] Using default worker.
# [12/09/2021 14:14:16 INFO 140151864076096] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [12/09/2021 14:14:16 INFO 140151864076096] Create Store: dist_async
# [12/09/2021 14:14:15 INFO 140250892990272] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-159-204.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-12-09-14-10-41-014', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:634103918907:training-job/kmeans-2021-12-09-14-10-41-014', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/347cec1c-e8cb-4ced-8a23-6254394f91cb', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'ap-northeast-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2369ce93-91d0-48d6-aa4c-46326af5e73a', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/2369ce93-91d0-48d6-aa4c-46326af5e73a', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.189.6', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 1 is a worker.
# [12/09/2021 14:14:15 INFO 140250892990272] Using default worker.
# [12/09/2021 14:14:15 INFO 140250892990272] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [12/09/2021 14:14:15 INFO 140250892990272] Create Store: dist_async
# [12/09/2021 14:14:17 INFO 140250892990272] nvidia-smi: took 0.032 seconds to run.
# [12/09/2021 14:14:17 INFO 140250892990272] nvidia-smi identified 0 GPUs.
# [12/09/2021 14:14:17 INFO 140250892990272] Number of GPUs being used: 0
# [12/09/2021 14:14:17 INFO 140250892990272] Checkpoint loading and saving are disabled.
# [12/09/2021 14:14:17 INFO 140151864076096] nvidia-smi: took 0.029 seconds to run.
# [12/09/2021 14:14:17 INFO 140151864076096] nvidia-smi identified 0 GPUs.
# [12/09/2021 14:14:17 INFO 140151864076096] Number of GPUs being used: 0
# [12/09/2021 14:14:17 INFO 140151864076096] Checkpoint loading and saving are disabled.
# [12/09/2021 14:14:17 INFO 140151864076096] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [12/09/2021 14:14:17 INFO 140151864076096] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [12/09/2021 14:14:17 INFO 140151864076096] Number of GPUs being used: 0
# [12/09/2021 14:14:17 INFO 140151864076096] number of center slices 1
# #metrics {"StartTime": 1639059257.7281933, "EndTime": 1639059257.7282279, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [2021-12-09 14:14:17.743] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 81, "num_examples": 1, "num_bytes": 15820000}
# [2021-12-09 14:14:17.948] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 203, "num_examples": 5, "num_bytes": 79100000}
# [12/09/2021 14:14:17 INFO 140151864076096] processed a total of 25000 examples
# [12/09/2021 14:14:17 INFO 140151864076096] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1639059257.7438602, "EndTime": 1639059257.9486055, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [12/09/2021 14:14:17 INFO 140151864076096] #throughput_metric: host=algo-1, train throughput=121994.53885683637 records/second
# [12/09/2021 14:14:17 INFO 140151864076096] shrinking 100 centers into 10
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #0. Current mean square distance 11.656032
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #1. Current mean square distance 11.197008
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #2. Current mean square distance 11.178638
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #3. Current mean square distance 11.080146
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #4. Current mean square distance 10.852211
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #5. Current mean square distance 11.130089
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #6. Current mean square distance 11.122182
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #7. Current mean square distance 10.871487
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #8. Current mean square distance 11.005980
# [12/09/2021 14:14:18 INFO 140151864076096] local kmeans attempt #9. Current mean square distance 10.799526
# [12/09/2021 14:14:18 INFO 140151864076096] finished shrinking process. Mean Square Distance = 11
# [12/09/2021 14:14:18 INFO 140151864076096] #quality_metric: host=algo-1, train msd <loss>=10.79952621459961
# [12/09/2021 14:14:18 INFO 140151864076096] compute all data-center distances: inner product took: 38.1501%, (0.080554 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] batch data loading with context took: 21.6337%, (0.045680 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] compute all data-center distances: point norm took: 12.1026%, (0.025555 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] gradient: cluster center took: 8.6953%, (0.018360 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] collect from kv store took: 5.8609%, (0.012375 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] splitting centers key-value pair took: 4.0508%, (0.008553 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] gradient: one_hot took: 3.4064%, (0.007193 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] predict compute msd took: 3.0758%, (0.006495 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] gradient: cluster size  took: 1.5219%, (0.003213 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] update state and report convergance took: 0.8445%, (0.001783 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] compute all data-center distances: center norm took: 0.4845%, (0.001023 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] update set-up time took: 0.1175%, (0.000248 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] predict minus dist took: 0.0561%, (0.000118 secs)
# [12/09/2021 14:14:18 INFO 140151864076096] TOTAL took: 0.2111504077911377
# [12/09/2021 14:14:18 INFO 140151864076096] Number of GPUs being used: 0
# #metrics {"StartTime": 1639059257.6616602, "EndTime": 1639059258.3055408, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 42.173147201538086, "count": 1, "min": 42.173147201538086, "max": 42.173147201538086}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 204.46515083312988, "count": 1, "min": 204.46515083312988, "max": 204.46515083312988}, "_shrink.time": {"sum": 352.83517837524414, "count": 1, "min": 352.83517837524414, "max": 352.83517837524414}, "finalize.time": {"sum": 356.02593421936035, "count": 1, "min": 356.02593421936035, "max": 356.02593421936035}, "model.serialize.time": {"sum": 0.21529197692871094, "count": 1, "min": 0.21529197692871094, "max": 0.21529197692871094}}}
# [12/09/2021 14:14:18 INFO 140151864076096] Test data is not provided.
# #metrics {"StartTime": 1639059258.3056164, "EndTime": 1639059258.3058262, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 31.383991241455078, "count": 1, "min": 31.383991241455078, "max": 31.383991241455078}, "totaltime": {"sum": 2050.459623336792, "count": 1, "min": 2050.459623336792, "max": 2050.459623336792}}}
# [12/09/2021 14:14:17 INFO 140250892990272] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [12/09/2021 14:14:17 INFO 140250892990272] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [12/09/2021 14:14:17 INFO 140250892990272] Number of GPUs being used: 0
# [12/09/2021 14:14:17 INFO 140250892990272] number of center slices 1
# #metrics {"StartTime": 1639059257.7336261, "EndTime": 1639059257.7336571, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [2021-12-09 14:14:17.747] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 77, "num_examples": 1, "num_bytes": 15820000}
# [2021-12-09 14:14:17.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 198, "num_examples": 5, "num_bytes": 79100000}
# [12/09/2021 14:14:17 INFO 140250892990272] processed a total of 25000 examples
# [12/09/2021 14:14:17 INFO 140250892990272] #progress_metric: host=algo-2, completed 100.0 % of epochs
# #metrics {"StartTime": 1639059257.7477093, "EndTime": 1639059257.946598, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [12/09/2021 14:14:17 INFO 140250892990272] #throughput_metric: host=algo-2, train throughput=125620.69015090162 records/second
# [12/09/2021 14:14:17 INFO 140250892990272] shrinking 100 centers into 10
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #0. Current mean square distance 11.369734
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #1. Current mean square distance 10.854623
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #2. Current mean square distance 11.061765
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #3. Current mean square distance 11.036377
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #4. Current mean square distance 11.310045
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #5. Current mean square distance 11.139559
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #6. Current mean square distance 10.807768
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #7. Current mean square distance 10.792585
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #8. Current mean square distance 10.875828
# [12/09/2021 14:14:18 INFO 140250892990272] local kmeans attempt #9. Current mean square distance 10.701517
# [12/09/2021 14:14:18 INFO 140250892990272] finished shrinking process. Mean Square Distance = 11
# [12/09/2021 14:14:18 INFO 140250892990272] #quality_metric: host=algo-2, train msd <loss>=10.701517105102539
# [12/09/2021 14:14:18 INFO 140250892990272] compute all data-center distances: inner product took: 37.1297%, (0.076182 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] batch data loading with context took: 22.5610%, (0.046290 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] compute all data-center distances: point norm took: 11.9580%, (0.024535 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] collect from kv store took: 8.2986%, (0.017027 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] gradient: cluster center took: 6.8430%, (0.014040 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] splitting centers key-value pair took: 4.0275%, (0.008264 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] gradient: one_hot took: 3.2104%, (0.006587 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] predict compute msd took: 3.0364%, (0.006230 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] gradient: cluster size  took: 1.4586%, (0.002993 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] update state and report convergance took: 0.7904%, (0.001622 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] compute all data-center distances: center norm took: 0.5346%, (0.001097 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] update set-up time took: 0.0934%, (0.000192 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] predict minus dist took: 0.0584%, (0.000120 secs)
# [12/09/2021 14:14:18 INFO 140250892990272] TOTAL took: 0.20517802238464355
# [12/09/2021 14:14:18 INFO 140250892990272] Number of GPUs being used: 0
# [12/09/2021 14:14:18 INFO 140250892990272] No model is serialized on a non-master node
# #metrics {"StartTime": 1639059257.669469, "EndTime": 1639059258.2819443, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 40.20571708679199, "count": 1, "min": 40.20571708679199, "max": 40.20571708679199}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 198.6830234527588, "count": 1, "min": 198.6830234527588, "max": 198.6830234527588}, "_shrink.time": {"sum": 325.79946517944336, "count": 1, "min": 325.79946517944336, "max": 325.79946517944336}, "finalize.time": {"sum": 328.30286026000977, "count": 1, "min": 328.30286026000977, "max": 328.30286026000977}, "model.serialize.time": {"sum": 0.06031990051269531, "count": 1, "min": 0.06031990051269531, "max": 0.06031990051269531}}}
# [12/09/2021 14:14:18 INFO 140250892990272] Test data is not provided.
# #metrics {"StartTime": 1639059258.2820535, "EndTime": 1639059258.2822285, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 8551.8217086792, "count": 1, "min": 8551.8217086792, "max": 8551.8217086792}, "totaltime": {"sum": 11110.265016555786, "count": 1, "min": 11110.265016555786, "max": 11110.265016555786}}}
#
# 2021-12-09 14:14:31 Uploading - Uploading generated training model
# 2021-12-09 14:14:31 Completed - Training job completed
# Training seconds: 108
# Billable seconds: 108

# %%
# %%time 
kmeans_predictor = kmeans.deploy(initial_instance_count=1, 
                                instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ----------!CPU times: user 193 ms, sys: 9.46 ms, total: 202 ms
# Wall time: 5min 1s

# %%
result = kmeans_predictor.predict(valid_set[0][30:31]) 
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 1.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 5.685048580169678
#     }
#   }
# }
# ]

# %%
# vaild set에 있는 0번에서 99번까지의 데이터로 클러스터를 예측합니다.
result = kmeans_predictor.predict(valid_set[0][0:100]) 
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result] 
for cluster in range(10): 
    print('\n\n\nCluster {}:'.format(int(cluster))) 
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ] 
    height = ((len(digits)-1)//5) + 1 
    width = 5 
    plt.rcParams["figure.figsize"] = (width,height) 
    _, subplots = plt.subplots(height, width) 
    subplots = numpy.ndarray.flatten(subplots) 
    for subplot, image in zip(subplots, digits): 
        show_digit(image, subplot=subplot) 
    for subplot in subplots[len(digits):]: 
        subplot.axis('off') 
    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:
